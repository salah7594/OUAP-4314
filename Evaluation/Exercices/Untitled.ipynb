# %%
import requests
import json
from pprint import pprint
import re

url = "https://api.qwant.com/api/search/news?count=10&q=sport&t=news&safesearch=1&locale=fr_FR"
var_headers = {
    'Origin': 'https://www.qwant.com',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7,ca;q=0.6,de;q=0.5,pt;q=0.4,sk;q=0.3,vi;q=0.2,ru;q=0.1,it;q=0.1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.167 Safari/537.36',
    'Content-type': 'application/x-www-form-urlencoded',
    'Accept': '*/*',
    'Referer': 'https://www.qwant.com/',
    'Connection': 'keep-alive',
    'DNT': '1',
}
response = requests.get(url, headers=var_headers)
response_json = json.loads(response.text)

# %%
response_json["data"]["result"]["items"][0]
# Out:
# {'_id': '3c0df5f0da727f088c04fe9127f2641c',
#  'category': 'sports',
#  'date': 1520681794,
#  'desc': "La première étape du Rallye du Mexique a été un chemin de croix pour M-<b>Sport</b>. Sébastien Ogier est le seul rescapé de l'étape, ses coéquipiers Elfyn Evans et...",
#  'desc_short': 'La première étape du Rallye du Mexique a été un chemin de croix pour M-<b>Sport</b>. Sébastien Ogier est le seul...',
#  'domain': 'autohebdo.fr',
#  'media': [{'pict': {'height': 110,
#     'type': 'image',
#     'url': '//s2.qwant.com/thumbr/0x110/d/6/5e57843683ace90a94a3e75ad9b204/b_1_q_0_p_0.jpg?u=http%3A%2F%2Fwww.autohebdo.fr%2Fsites%2Fdefault%2Ffiles%2Factualites%2Fogier-mexico8785.jpg&q=0&b=1&p=0&a=0',
#     'width': 0},
#    'pict_big': {'height': 240,
#     'type': 'image',
#     'url': '//s2.qwant.com/thumbr/0x240/7/2/644af98dc60a2664bd9d435ba9c76a/b_1_q_0_p_0.jpg?u=http%3A%2F%2Fwww.autohebdo.fr%2Fsites%2Fdefault%2Ffiles%2Factualites%2Fogier-mexico8785.jpg&q=0&b=1&p=0&a=0',
#     'width': 0}}],
#  'title': 'Ogier console M-<b>Sport</b> au Mexique',
#  'url': 'http://www.autohebdo.fr/wrc/actualites/ogier-console-m-sport-au-mexique-192891.html'}

# %%
#titre de la page?
#image: bof.

var_list = []
for x in response_json["data"]["result"]["items"]:
    if(len(x["media"]))>0:
        var_image = x["media"][0]["pict"]["url"]
    var_list.append(
    {
        "url": x["url"],
        "domain": x["domain"],
        "category": x["category"],
        "title_article": re.sub('<[^<]+?>', '', x["title"]),
        "image": var_image, 
        "description": re.sub('<[^<]+?>', '', x["desc"]),
        "description_short": re.sub('<[^<]+?>', '', x["desc_short"])
        
    }
    )
pprint(var_list)
# Out:
# [{'category': 'sports',
#   'description': 'La première étape du Rallye du Mexique a été un chemin de '
#                  'croix pour M-Sport. Sébastien Ogier est le seul rescapé de '
#                  "l'étape, ses coéquipiers Elfyn Evans et...",
#   'description_short': 'La première étape du Rallye du Mexique a été un chemin '
#                        'de croix pour M-Sport. Sébastien Ogier est le seul...',
#   'domain': 'autohebdo.fr',
#   'image': '//s2.qwant.com/thumbr/0x110/d/6/5e57843683ace90a94a3e75ad9b204/b_1_q_0_p_0.jpg?u=http%3A%2F%2Fwww.autohebdo.fr%2Fsites%2Fdefault%2Ffiles%2Factualites%2Fogier-mexico8785.jpg&q=0&b=1&p=0&a=0',
#   'title_article': 'Ogier console M-Sport au Mexique',
#   'url': 'http://www.autohebdo.fr/wrc/actualites/ogier-console-m-sport-au-mexique-192891.html'},
#  {'category': 'department',
#   'description': "Le PSG et l'AC Milan ont le point commun d'avoir connu une "
#                  'bien mauvaise semaine européenne. Autre élément qui '
#                  'rapproche les deux clubs, le gardien de but Gianluigi...',
#   'description_short': "Le PSG et l'AC Milan ont le point commun d'avoir connu "
#                        'une bien mauvaise semaine européenne. Autre élément '
#                        'qui...',
#   'domain': 'canal-supporters.com',
#   'image': '//s1.qwant.com/thumbr/0x110/8/5/67cd1250f04c56214e6519dffe30db/b_1_q_0_p_0.jpg?u=http%3A%2F%2Fcanal-supporters.com%2Fwp-content%2Fuploads%2F2018%2F03%2Fcds.png&q=0&b=1&p=0&a=0',
#   'title_article': 'Donnarumma va au PSG (Corriere dello Sport)',
#   'url': 'http://canal-supporters.com/2018/03/donnarumma-va-au-psg-corriere-dello-sport/'},
#  {'category': '',
#   'description': "Qui a dit qu'un legging devait forcément être noir pour "
#                  'faire du sport ? Pas les Poulettes Fitness en tout cas ! La '
#                  'marque lyonnaise de vêtements de sport veut faire...',
#   'description_short': "Qui a dit qu'un legging devait forcément être noir "
#                        'pour faire du sport ? Pas les Poulettes Fitness en '
#                        'tout cas...',
#   'domain': 'lyonmag.com',
#   'image': '//s1.qwant.com/thumbr/0x110/9/2/44e5b3190063bc7125a13c698812cd/b_1_q_0_p_0.jpg?u=https%3A%2F%2Fwww.lyonmag.com%2Fmedias%2Fimages%2Fpoulettesune.jpg&q=0&b=1&p=0&a=0',
#   'title_article': 'Les Poulettes Fitness, la marque lyonnaise qui donne des '
#                    'couleurs aux tenues de sport',
#   'url': 'https://www.lyonmag.com/article/94059/les-poulettes-fitness-la-marque-lyonnaise-qui-donne-des-couleurs-aux-tenues-de-sport'},
#  {'category': '',
#   'description': 'Fort du succès des quatre premières éditions, la Fédération '
#                  "sportive des ASPTT reconduit l'événement Le sport donne des "
#                  "Elles à l'occasion de la...",
#   'description_short': 'Fort du succès des quatre premières éditions, la '
#                        "Fédération sportive des ASPTT reconduit l'événement "
#                        'Le...',
#   'domain': 'republicain-lorrain.fr',
#   'image': '//s1.qwant.com/thumbr/0x110/0/a/1e59dcd7fd2e991cd4758cbd8d53d6/b_1_q_0_p_0.jpg?u=https%3A%2F%2Fcdn-s-www.republicain-lorrain.fr%2Fimages%2F53FA5EF3-0787-4B3E-B86D-425630B661DB%2FERV_11FB%2Fphoto-1520587188.jpg&q=0&b=1&p=0&a=0',
#   'title_article': "Aujourd'hui à Metz : le sport donne des Elles",
#   'url': 'https://www.republicain-lorrain.fr/edition-de-metz-ville/2018/03/09/aujourd-hui-a-metz-le-sport-donne-des-elles'},
#  {'category': 'video_game',
#   'description': 'Gran Turismo est un jeu de course automobile qui penche '
#                  "plutôt du côté simulation. Fan d'arcade, passez votre "
#                  "chemin. Alors oui il n'est pas aussi compliqué que les...",
#   'description_short': 'Gran Turismo est un jeu de course automobile qui '
#                        "penche plutôt du côté simulation. Fan d'arcade, passez "
#                        'votre chemin.',
#   'domain': 'maxoe.com',
#   'image': '//s1.qwant.com/thumbr/0x110/8/8/451c0748030210ae64657cbb53eca0/b_1_q_0_p_0.jpg?u=http%3A%2F%2Fwww.maxoe.com%2Fimg%2Fuploads%2F2018%2F03%2FGTSport-1.jpg&q=0&b=1&p=0&a=0',
#   'title_article': 'Retour sur Gran Turismo Sport : il se bonifie avec le '
#                    'temps',
#   'url': 'http://www.maxoe.com/games/jeux-articles/tests-ps4/retour-sur-gran-turismo-sport-il-se-bonifie-avec-le-temps/'},
#  {'category': 'sports',
#   'description': "Le sport en direct sur L'ÉQUIPE. Les informations, résultats "
#                  'et classements de tous les sports. Directs commentés, images '
#                  'et vidéos à regarder et à partager...',
#   'description_short': "Le sport en direct sur L'ÉQUIPE. Les informations, "
#                        'résultats et classements de tous les sports. '
#                        'Directs...',
#   'domain': 'lequipe.fr',
#   'image': '//s1.qwant.com/thumbr/0x110/8/8/451c0748030210ae64657cbb53eca0/b_1_q_0_p_0.jpg?u=http%3A%2F%2Fwww.maxoe.com%2Fimg%2Fuploads%2F2018%2F03%2FGTSport-1.jpg&q=0&b=1&p=0&a=0',
#   'title_article': "L'ÉQUIPE - L'actualité du sport en continu.",
#   'url': 'https://www.lequipe.fr/Football/Actualites/Lille-kevin-malcuit-pas-dans-le-groupe-pour-montpellier/882748'},
#  {'category': '',
#   'description': 'Mercredi 14 mars 2018, 1 800 lycéennes de Normandie vont '
#                  'participer à "La Lycéenne Maif Run", une color run qui vise '
#                  'à promouvoir la pratique du sport chez les...',
#   'description_short': 'Mercredi 14 mars 2018, 1 800 lycéennes de Normandie '
#                        'vont participer à "La Lycéenne Maif Run", une color '
#                        'run qui vise...',
#   'domain': 'actu.fr',
#   'image': '//s2.qwant.com/thumbr/0x110/4/0/6d9261d580741e40e394fab7d91853/b_1_q_0_p_0.jpg?u=https%3A%2F%2Fstatic.actu.fr%2Fuploads%2F2018%2F03%2FLa-Lyc%25C3%25A9enne-%25C2%25A9UNSS-854x567.jpg&q=0&b=1&p=0&a=0',
#   'title_article': 'Près de Caen, 1 800 lycéennes vont courir pour défendre la '
#                    'pratique du sport chez les adolescentes',
#   'url': 'https://actu.fr/normandie/herouville-saint-clair_14327/pres-caen-1-800-lyceennes-vont-courir-defendre-pratique-sport-chez-adolescentes_15848018.html'},
#  {'category': 'politics',
#   'description': 'Thomas Thouroude a quitté «dès ce vendredi» le magazine '
#                  "«Tout le sport» qu'il animait sur France 3 depuis la "
#                  'rentrée, a indiqué France Télévisions...',
#   'description_short': 'Thomas Thouroude a quitté «dès ce vendredi» le '
#                        "magazine «Tout le sport» qu'il animait sur France 3 "
#                        'depuis...',
#   'domain': 'liberation.fr',
#   'image': '//s2.qwant.com/thumbr/0x110/c/2/303339ae881afb22d69de37e3e1918/b_1_q_0_p_0.jpg?u=http%3A%2F%2Fmd1.libe.com%2Fphoto%2F1103424-thomas-thouroude-l-animateur-du-magazine-tout-le-sport-lors-des-victoires-de-la-musique-le-10-fevrie.jpg&q=0&b=1&p=0&a=0',
#   'title_article': '«Tout le sport»: saison terminée pour Thomas Thouroude sur '
#                    'France 3',
#   'url': 'http://www.liberation.fr/sports/2018/03/09/tout-le-sport-saison-terminee-pour-thomas-thouroude-sur-france-3_1635002'},
#  {'category': '',
#   'description': "Je n'aime pas faire du sport le matin. D'ailleurs, je ne "
#                  'suis pas du matin. Je déteste me lever tôt, et tout ce que '
#                  "j'arrive à faire en me levant, c'est d'aller me...",
#   'description_short': "Je n'aime pas faire du sport le matin. D'ailleurs, je "
#                        'ne suis pas du matin. Je déteste me lever tôt, et tout '
#                        'ce...',
#   'domain': 'sobusygirls.fr',
#   'image': '//s1.qwant.com/thumbr/0x110/0/9/200698f2293854749408c9254cb3f2/b_1_q_0_p_0.jpg?u=http%3A%2F%2Fsobusygirls.fr%2Fuploads%2Fpost%2Flarge%2F4bc04314e612b0cd406a178c430afeab8111f1e2.jpeg&q=0&b=1&p=0&a=0',
#   'title_article': 'Pourquoi vous devriez faire du sport le soir plutôt que le '
#                    'matin (si si !)',
#   'url': 'http://sobusygirls.fr/2018/03/07/quand-faire-du-sport-le-soir-le-matin/'},
#  {'category': '',
#   'description': "L'animateur de Tout le sport avait déploré, dans un "
#                  "entretien à L'Equipe, le manque de considération de la "
#                  'chaîne à son encontre',
#   'description_short': "L'animateur de Tout le sport avait déploré, dans un "
#                        "entretien à L'Equipe...",
#   'domain': 'lexpress.fr',
#   'image': '//s1.qwant.com/thumbr/0x110/a/9/0cfc2145a245f72ea701244ae64185/b_1_q_0_p_0.jpg?u=https%3A%2F%2Fstatic.lexpress.fr%2Fmedias_11421%2Fw_1988%2Ch_1492%2Cc_crop%2Cx_58%2Cy_0%2Fw_605%2Ch_350%2Cc_fill%2Cg_north%2Fv1490100486%2Fthomas-thouroude-le-10-fevrier-2017-lors-des-32e-victoires-de-la-musique-a-paris_5847621.jpg&q=0&b=1&p=0&a=0',
#   'title_article': '"Tout le sport": France Télé se sépare définitivement de '
#                    'Thomas Thouroude',
#   'url': 'https://www.lexpress.fr/actualite/medias/tout-le-sport-france-tele-se-separe-definitivement-de-thomas-thouroude_1991184.html'}]
